# %% [markdown]
# # Text To Speech Demo

# %% [markdown]
# ## Info

# %%
# Import modules
from utils.ImageHandeling import BasicImageHandeling as bh
from utils.TextToSpeechFromImage import TextToSpeech as tts
from utils.RectangleUI import RectangleDrawer

# %%
image_path = 'assets/DEMO_image.jpg'
image = bh.read_image(image_path)

# %%
bh.save_output_image(image, # Check data folder for success
                     image_name='roi_rect.jpg') # Default

# %%
bh.show_image(image)

# %% [markdown]
# ### Find Dominant Colors

# %%
cols = bh.find_dominant_colors(image) # output is rgb

# %%
cols # In order of dominance
# Out:
# array([[252, 253, 253],
#        [  7, 142,  60],
#        [ 69, 126, 152]])

# %%
# Display the colors:
for i in cols:
    bh.display_color(i) # Input is rgb

# %% [markdown]
# ### Find Title

# %%
biggest_title = tts.extract_biggest_title(image)
biggest_title
# Out:
# 'Alvedon'

# %% [markdown]
# ## Create ROIs

# %% [markdown]
# ### Divide Image By Coordinates (ROI)

# %%
bh.show_image(image)

# %%
image_txt = tts.extract_text_from_image(image)
print(image_txt)
# Out:
# Alvedon, filmdragerad tablett 500 mg, 20 st
# (Z Fler än 100 st i lager 32 kr
# 20 lmdragerade tablette os (Z Gratis fraktalternativ
# ä0a S Jämförpris: 1,60 kelst
# HAlvedon 500mg
# paracetamol
# Det här ör ett receptfritt läkemedel. Läs bipacksedeln noga före användning.
# Filmdragerade tabletter
# vid tilltällig smärta och teber SN Beskrivning d
# Alvedon, filmdragerad tablett 500 mg kan användas vid lindrig smärta (t.ex. huvudvärk) och som
# febernedsättande vid exempelvis en förkylning. Rekommenderas inte till barn under 3 år. Effekten av
# smärtlindring med Alvedon varar normalt i 4-5 timmar.
# ä Alvedon innehåller det verksamma ämnet paracetamol. Paracetamol kan användas av personer med
# 'Alvedon känslig mage eller ökad blödningsbenägenhet. Tabletten är filmdragerad vilket gör den lättare att svälja.
# Barn kan ha Iite svårt att svälja tabletter, du kan då försöka med paracetamol i flytande form eller som
# 2 suppositorium (stolpiller), dessa du hittar i kategorin feber hos barn.
# välvald
# Om du har Alvedon utskriven på recept kan du hämta ut det hos oss genom att logga in med e-
# legitimation.
# Dosering & användning A
# Observera! Högre doser än de rekommenderade innebär risk för mycket allvarlig leverskada. Alvedon ska
# ej användas för långvarigt bruk annat än på läkares ordination. Om läkare inte gett dig annan dosering
# ska du följa doseringen nedan. Vuxna och barn över 40 kg (från 12 år): 1-2 tabletter var 4-6 timme, högst
# 8 tabletter per dygn. Barn: Till barn ska doseringen i första hand beräknas efter barnets vikt. Barn 25-40
# kg (ca 7-12 år): 141 tablett var 4-6 timme, högst 4 tabletter per dygn. Barn 15-25 kg (ca 3-7 år): 3 tablett
# var 4-6 timme, högst 2 tabletter per dygn. Alvedon tablett 500 mg rekommenderas inte till barn som
# väger mindre än 15 kg, välj istället Alvedon oral lösning eller Alvedon suppositorier. Använd inte Alvedon
# till barn i mer än 2 dygn om inte läkare föreskriver annat.
# Innehåll A
# Den aktiva substansen är paracetamol 500 mg. Övriga innehållsämnen är: Majsstärkelse, pregelatiniserad
# stärkelse (majs), povidon, kaliumsorbat, talk, stearinsyra, hypromellos, triacetin.
# Produktfakta A
# EAN: 7046260976108
# Varumärke: Alvedon
# Kategori: Feber & Värk
# Feber & Värk > Feber > Febernedsättande
# Feber & Värk > Huvudvärk
# Feber & Värk > Ledvärk
# Feber & Värk > Mensvärk
# Feber & Värk > Rygg- & Nackvärk
# Feber & Värk > Tandvärk
# Bäst före-datum: — 2025-05-31 &
# Klassificering: Receptfritt läkemedel
# Förpackningsstorlek: 20 st

# %% [markdown]
# ### Use module RectangleUI to gain coords + roi images

# %%
# NOTE : To user, for this DEMO, only define 2 ROIs for the code to work.
#        You can also skip this step and input the ROI coords manually.

drawer = RectangleDrawer(image_path)
# Run the window (UI)
drawer.start_window()
# Draw
drawer.draw_rectangle()

drawer.wait_for_input()

# %%
# Define coordinates manually here:

# %%
# Get the coords of the rectangles
coords = drawer.get_rectangle_coordinates()
print(coords)
# Out:
# [(356, 226, 995, 508, 639, 282), (345, 189, 828, 221, 483, 32)]

# %%
# Optional : get an image showing the rectangles on the image (To ensure the input)
image_with_rectangle = drawer.get_image_with_rectangles() # Extra
bh.show_image(image_with_rectangle)

# %%
bh.save_output_image(image_with_rectangle, # Check data folder for success
                     image_name='roi_rect.jpg') # Default

# %%
images = drawer.get_roi_images(coords)

image_1, image_2 = images # NOTE: Only Define as many images as you have!

images
# Out:
# [array([[[255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255],
#          ...,
#          [255, 255, 249],
#          [255, 255, 248],
#          [255, 255, 251]],
#
#         [[255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255],
#          ...,
#          [255, 255, 249],
#          [255, 255, 248],
#          [255, 255, 249]],
#
#         [[255, 254, 255],
#          [255, 255, 255],
#          [255, 254, 255],
#          ...,
#          [255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255]],
#
#         ...,
#
#         [[255, 254, 255],
#          [255, 255, 255],
#          [255, 254, 255],
#          ...,
#          [251, 251, 251],
#          [255, 255, 255],
#          [255, 254, 255]],
#
#         [[255, 253, 255],
#          [254, 253, 255],
#          [255, 253, 255],
#          ...,
#          [252, 254, 255],
#          [253, 255, 255],
#          [253, 254, 255]],
#
#         [[253, 255, 255],
#          [253, 255, 255],
#          [253, 255, 255],
#          ...,
#          [251, 255, 255],
#          [250, 255, 253],
#          [250, 255, 254]]], dtype=uint8),
#  array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8)]

# %%
print(image_1) # First ROI image
# Out:
# [[[255 254 255]
#   [255 254 255]
#   [255 254 255]
#   ...
#   [255 255 249]
#   [255 255 248]
#   [255 255 251]]
#
#  [[255 254 255]
#   [255 254 255]
#   [255 254 255]
#   ...
#   [255 255 249]
#   [255 255 248]
#   [255 255 249]]
#
#  [[255 254 255]
#   [255 255 255]
#   [255 254 255]
#   ...
#   [255 254 255]
#   [255 254 255]
#   [255 254 255]]
#
#  ...
#
#  [[255 254 255]
#   [255 255 255]
#   [255 254 255]
#   ...
#   [251 251 251]
#   [255 255 255]
#   [255 254 255]]
#
#  [[255 253 255]
#   [254 253 255]
#   [255 253 255]
#   ...
#   [252 254 255]
#   [253 255 255]
#   [253 254 255]]
#
#  [[253 255 255]
#   [253 255 255]
#   [253 255 255]
#   ...
#   [251 255 255]
#   [250 255 253]
#   [250 255 254]]]

# %%
# Show the first ROI image
bh.show_image(image_1)

# %%
bh.show_image(image_2)

# %% [markdown]
# ## Text To Speech

# %% [markdown]
# ### Prepare Text

# %%
# NOTE: Change the following variable to switch between images/rois:

test_roi = image_1

# %%
bh.show_image(test_roi)

# %%
# Test Getting titles:
tts.extract_biggest_title(test_roi)
# Out:
# 'Beskrivning'

# %%
# Extract text 
test_roi_text = tts.extract_text_from_image(test_roi)

# %%
# Enhance before
test_roi_enhanced = tts.enhance_image(test_roi)

# Optimal : Show the enchanced image that the computer 'sees' visually.
bh.show_image(test_roi_enhanced)

# %%
# Extract from enhanced :
enhanced_test_roi_text = tts.extract_text_from_image(test_roi)
print(enhanced_test_roi_text)
# Out:
# Beskrivning H
# Alvedon, filmdragerad tablett 500 mg kan användas vid lindrig smärta (t.ex. huvudvärk) och som
# febernedsättande vid exempelvis en förkylning. Rekommenderas inte till barn under 3 år. Effekten av
# smärtlindring med Alvedon varar normalt i 4-5 timmar.
#
# Alvedon innehåller det verksamma ämnet paracetamol. Paracetamol kan användas av personer med
# känslig mage eller ökad blödningsbenägenhet. Tabletten är filmdragerad vilket gör den lättare att svälja.
# Barn kan ha lite svårt att svälja tabletter, du kan då försöka med paracetamol i flytande form eller som
# suppositorium (stolpiller), dessa du hittar i kategorin feber hos barn.
#
# Om du har Alvedon utskriven på recept kan du hämta ut det hos oss genom att logga in med e-
# legitimation.

# %% [markdown]
# ### Summarize Text

# %%
summarized_text = tts.summarize_text(enhanced_test_roi_text,
                                     max_char=300, # Default
                                     summary_div=3) # Default

# %%
print(summarized_text)
# Out:
# Alvedon 500 mg is used for mild pain relief and reducing fever. Not recommended for children under 3. Contains paracetamol which is gentle on the stomach. Available in film-coated tablets. Can be obtained with a prescription online.

# %%
len(enhanced_test_roi_text)/len(summarized_text)
# amount of characters are reduced by following nr :
# Out:
# 3.2198275862068964

# %%
from utils.TextToSpeechFromImage import count_words
# Se wordcount:
sen_len , sen = count_words(summarized_text,
                            ret_words = True) # Default False
print(sen_len)
# Out:
# 37

# %%
# If you want access to the split words, pass ret_words=True (default False)
sen
# Out:
# ['Alvedon',
#  '500',
#  'mg',
#  'is',
#  'used',
#  'for',
#  'mild',
#  'pain',
#  'relief',
#  'and',
#  'reducing',
#  'fever.',
#  'Not',
#  'recommended',
#  'for',
#  'children',
#  'under',
#  '3.',
#  'Contains',
#  'paracetamol',
#  'which',
#  'is',
#  'gentle',
#  'on',
#  'the',
#  'stomach.',
#  'Available',
#  'in',
#  'film-coated',
#  'tablets.',
#  'Can',
#  'be',
#  'obtained',
#  'with',
#  'a',
#  'prescription',
#  'online.']

# %% [markdown]
# ### Read Out Text/Summary

# %%
tts.read_text(summarized_text)
